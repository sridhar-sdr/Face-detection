# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import cv2

# %%
from google.colab import files
from io import BytesIO
from PIL import Image

uploaded = files.upload()
img = Image.open(BytesIO(uploaded['sundar.jpg']))
# Out:
#      <input type="file" id="files-f57c2ad5-92f8-4bdf-a247-dff2417019a9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f57c2ad5-92f8-4bdf-a247-dff2417019a9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving sundar.jpg to sundar.jpg

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.imshow(img)
plt.show()
print(type(img))
image=np.array(img)
print(type(image))
# Out:
# <class 'PIL.JpegImagePlugin.JpegImageFile'>
# <class 'numpy.ndarray'>

# %%
#converting into Grayscale
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
plt.imshow(gray)
plt.show()

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-84953182-c7a3-4217-8ca1-3c582826a9d4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-84953182-c7a3-4217-8ca1-3c582826a9d4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving haarcascade_frontalface_default.xml to haarcascade_frontalface_default (2).xml

# %%
face_classifier = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
faces = face_classifier.detectMultiScale(gray, 1.3, 5)

# %%
from google.colab.patches import cv2_imshow

# We iterate through our faces array and draw a rectangle
# over each face in faces
for (x,y,w,h) in faces:
    cv2.rectangle(image, (x,y), (x+w,y+h), (127,0,255), 2)
    cv2_imshow(image)
    cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=990x520 at 0x7F70E2A10AC8>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-ed6465c4-a1d1-45eb-bb22-e8f8144efca0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ed6465c4-a1d1-45eb-bb22-e8f8144efca0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving haarcascade_eye.xml to haarcascade_eye.xml

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-4b9acdfd-e2ea-4ca3-889d-837b2ccb67db" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4b9acdfd-e2ea-4ca3-889d-837b2ccb67db">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving haarcascade_smile.xml to haarcascade_smile.xml

# %%
from google.colab.patches import cv2_imshow
eye_classifier = cv2.CascadeClassifier('haarcascade_eye.xml')
roi_gray = gray[y:y+h, x:x+w]
roi_color = image[y:y+h, x:x+w]
eyes = eye_classifier.detectMultiScale(roi_gray)
for (ex,ey,ew,eh) in eyes:
      cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(255,255,0),2)
      cv2_imshow(image)
      cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=990x520 at 0x7F70E2A73400>
# <PIL.Image.Image image mode=RGB size=990x520 at 0x7F70E2A73470>
# <PIL.Image.Image image mode=RGB size=990x520 at 0x7F70E2A73400>
# <PIL.Image.Image image mode=RGB size=990x520 at 0x7F70E2A73048>

# %%
# We iterate through our faces array and draw a rectangle
# over each face in faces
for (x,y,w,h) in faces:
    cv2.rectangle(image, (x,y), (x+w,y+h), (127,0,255), 2)
    cv2_imshow(image)
    cv2.waitKey(0)

# %%
smile_classifier = cv2.CascadeClassifier('haarcascade_smile.xml')
roi_gray = gray[y:y+h, x:x+w]
roi_color = image[y:y+h, x:x+w]
smiles = smile_classifier.detectMultiScale(roi_gray, 1.8, 20) 
for (sx, sy, sw, sh) in smiles: 
      cv2.rectangle(roi_color, (sx, sy), ((sx + sw), (sy + sh)), (0, 0, 255), 2)
      cv2_imshow(image)
      cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=990x520 at 0x7F70E2FF4F98>
